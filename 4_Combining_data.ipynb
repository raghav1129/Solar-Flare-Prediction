# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
unassociated = pd.read_excel(r'C:\Users\Raghav\Desktop\Solar Flare\Data\Unassociated_spots.xlsx')

# %%
#Contains 4425 rows of data - For spots that did not produce falres 
unassociated
# Out:
#       Unnamed: 0  level_0 Wilson Magnetic Classification  NOAA_Number_spots  \
# 0              0       10                            B                 7935
# 1              1       31                            B                 7937
# 2              2       40                            B                 7938
# 3              3       48                            B                 7940
# 4              4       50                            B                 7939
# ...          ...      ...                            ...                ...
# 4420        4420    98112                            A                12618
# 4421        4421    98122                            A                12619
# 4422        4422    98126                            A                12620
# 4423        4423    98133                            B                12621
# 4424        4424    98136                            A                12622
#
# ...

# %%
#Drop columns that are not required
unassociated = unassociated.drop(columns =['Unnamed: 0', 'level_0', 'index', 'Integrated_Flux', 'NOAA_Number_flare'], axis= 1)

# %%
associated = pd.read_excel(r'C:\Users\Raghav\Desktop\Solar Flare\Data\associated_spots_new.xlsx')

# %%
#Contains 13664 rows fo data for spots that prdocued flares 
associated
# Out:
#        Unnamed: 0 X_Ray_Class X_Ray_Intensity Integrated_Flux  \
# 0               0           C              10             NaN
# 1               1           C              13             NaN
# 2               2           C              15             NaN
# 3               3           C              16             NaN
# 4               4           C              12             NaN
# ...           ...         ...             ...             ...
# 13659       13659           C              23        2.6E-04
# 13660       13660           C              11        2.4E-04
# 13661       13661           C              12        2.9E-04
# 13662       13662           C              18        3.0E-03
# 13663       13663           C              12        7.7E-04
#
#        NOAA_Number_flare                Date Wilson Magnetic Classification  \
# 0                   7938 1996-01-03 07:04:02                            B
# ...

# %%
#drop columns that are not required
associated.drop(columns = ['Unnamed: 0', 'Integrated_Flux', 'NOAA_Number_flare'], axis = 1, inplace = True)

# %%
associated_C = associated[associated['X_Ray_Class'] == 'C']

# %%
associated_C
# Out:
#       X_Ray_Class X_Ray_Intensity                Date  \
# 0               C              10 1996-01-03 07:04:02
# 1               C              13 1996-01-03 07:04:02
# 2               C              15 1996-03-21 10:04:05
# 3               C              16 1996-04-20 06:02:04
# 4               C              12 1996-04-20 06:02:04
# ...           ...             ...                 ...
# 13659           C              23 2016-11-29 01:00:05
# 13660           C              11 2016-11-29 01:00:05
# 13661           C              12 2016-11-29 01:00:05
# 13662           C              18 2016-11-29 01:00:05
# 13663           C              12 2016-11-29 01:00:05
#
#       Wilson Magnetic Classification  NOAA_Number_spots Zurich Class  \
# 0                                B                 7938            C
# 1                                B                 7938            C
# 2                                B                 7953            B
# ...

# %%
associated_MX = associated[associated['X_Ray_Class'] != 'C']

# %%
associated_MX
# Out:
#       X_Ray_Class X_Ray_Intensity                Date  \
# 6               M              36 1996-04-20 06:02:04
# 15              M              14 1996-07-04 18:05:00
# 18              X              26 1996-07-04 18:05:00
# 20              M              10 1996-07-04 18:05:00
# 42              M              10 1996-11-21 12:03:00
# ...           ...             ...                 ...
# 13629           M              55 2016-07-15 01:03:08
# 13631           M              20 2016-07-15 01:03:08
# 13634           M              13 2016-08-05 03:02:05
# 13653           M              10 2016-11-29 01:00:05
# 13655           M              12 2016-11-29 01:00:05
#
#       Wilson Magnetic Classification  NOAA_Number_spots Zurich Class  \
# 6                                B                 7958            C
# 15                               B                 7978            B
# 18                               B                 7978            B
# ...

# %%
# Randomly sample spots that rpdouced flares of C class to balance datasets 
associated_C_randpm = associated_C.sample(n = 2652)

# %%
associated_C_randpm
# Out:
#       X_Ray_Class X_Ray_Intensity                Date  \
# 3432            C              11 2001-02-02 16:00:00
# 1558            C              23 1999-10-03 06:00:07
# 13607           C              68 2016-07-15 01:03:08
# 2178            C              28 2000-03-14 12:01:03
# 11919           C              23 2014-03-22 01:04:04
# ...           ...             ...                 ...
# 6519            C              89 2003-05-19 14:03:00
# 955             C              32 1999-02-09 16:03:08
# 4902            C              53 2002-02-03 00:03:00
# 5367            C              17 2002-07-09 01:04:05
# 6771            C              20 2003-07-19 14:04:07
#
#       Wilson Magnetic Classification  NOAA_Number_spots Zurich Class  \
# 3432                            (B )               9335
# 1558                             B                 8720            B
# 13607                            B                12567            B
# ...

# %%
associated_4225 = [associated_MX, associated_C_randpm]
associated_new = pd.concat(associated_4225)

# %%
#Contains 4425 rows for spots that produced flares 
associated_new
# Out:
#      X_Ray_Class X_Ray_Intensity                Date  \
# 6              M              36 1996-04-20 06:02:04
# 15             M              14 1996-07-04 18:05:00
# 18             X              26 1996-07-04 18:05:00
# 20             M              10 1996-07-04 18:05:00
# 42             M              10 1996-11-21 12:03:00
# ...          ...             ...                 ...
# 6519           C              89 2003-05-19 14:03:00
# 955            C              32 1999-02-09 16:03:08
# 4902           C              53 2002-02-03 00:03:00
# 5367           C              17 2002-07-09 01:04:05
# 6771           C              20 2003-07-19 14:04:07
#
#      Wilson Magnetic Classification  NOAA_Number_spots Zurich Class  \
# 6                               B                 7958            C
# 15                              B                 7978            B
# 18                              B                 7978            B
# ...

# %%
flares = [associated_new, unassociated]

# %%
Flares_Data = pd.concat(flares)

# %%
Flares_Data
# Out:
#      X_Ray_Class X_Ray_Intensity                Date  \
# 6              M              36 1996-04-20 06:02:04
# 15             M              14 1996-07-04 18:05:00
# 18             X              26 1996-07-04 18:05:00
# 20             M              10 1996-07-04 18:05:00
# 42             M              10 1996-11-21 12:03:00
# ...          ...             ...                 ...
# 4420         NaN             NaN 2016-12-15 15:05:08
# 4421         NaN             NaN 2016-12-21 07:01:00
# 4422         NaN             NaN 2016-12-23 07:05:00
# 4423         NaN             NaN 2016-12-28 19:00:08
# 4424         NaN             NaN 2016-12-31 07:02:00
#
#      Wilson Magnetic Classification  NOAA_Number_spots Zurich Class  \
# 6                               B                 7958            C
# 15                              B                 7978            B
# 18                              B                 7978            B
# ...

# %%
Flares_Data[Flares_Data['Status'] == 'Associated']
# Out:
#      X_Ray_Class X_Ray_Intensity                Date  \
# 6              M              36 1996-04-20 06:02:04
# 15             M              14 1996-07-04 18:05:00
# 18             X              26 1996-07-04 18:05:00
# 20             M              10 1996-07-04 18:05:00
# 42             M              10 1996-11-21 12:03:00
# ...          ...             ...                 ...
# 6519           C              89 2003-05-19 14:03:00
# 955            C              32 1999-02-09 16:03:08
# 4902           C              53 2002-02-03 00:03:00
# 5367           C              17 2002-07-09 01:04:05
# 6771           C              20 2003-07-19 14:04:07
#
#      Wilson Magnetic Classification  NOAA_Number_spots Zurich Class  \
# 6                               B                 7958            C
# 15                              B                 7978            B
# 18                              B                 7978            B
# ...

# %%
#Rename columns
Flares_Data.rename(columns= {'Wilson Magnetic Classification' : 'magnetic_classification',
                             'NOAA_Number_spots': 'NOAA',
                             'Zurich Class' : 'zurich_class',
                             'penumbra Class' : 'penumbra_class',
                             'Compactness Class' : 'compactness_class',
                             'Number of Spots' : 'No_of_spots',
                             'Longitudanal extent' :'longitudanal_extent'}, inplace = True)
Flares_Data
# Out:
#      X_Ray_Class X_Ray_Intensity                Date magnetic_classification  \
# 6              M              36 1996-04-20 06:02:04                     B
# 15             M              14 1996-07-04 18:05:00                     B
# 18             X              26 1996-07-04 18:05:00                     B
# 20             M              10 1996-07-04 18:05:00                     B
# 42             M              10 1996-11-21 12:03:00                     B
# ...          ...             ...                 ...                     ...
# 4420         NaN             NaN 2016-12-15 15:05:08                     A
# 4421         NaN             NaN 2016-12-21 07:01:00                     A
# 4422         NaN             NaN 2016-12-23 07:05:00                     A
# 4423         NaN             NaN 2016-12-28 19:00:08                     B
# 4424         NaN             NaN 2016-12-31 07:02:00                     A
#
# ...

# %%
Flares_Data.to_excel('sunspots_new.xlsx')

# %%
Flares_Data['Status'].value_counts()
# Out:
# Associated      4425
# Unassociated    4425
# Name: Status, dtype: int64
